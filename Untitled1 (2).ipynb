# %%
###1.Abstract

# %%
###Small summary of the whole paper

# %%
###2. Introduction

# %% [markdown]
# 2. Introduction
#
# Music is fundamentally a physical and mathematical phenomenon. Every musical note corresponds to a sound wave vibrating at a specific frequency. When two or more notes are played together, their interaction creates what humans perceive as harmony.
#
# Understanding why certain combinations of notes sound pleasant while others do not has been a central question in both music theory and mathematics.
#
# One of the earliest mathematical investigations of music is attributed to the ancient Greek mathematician Pythagoras. Through experiments with vibrating strings, he discovered that harmonious musical intervals correspond to simple ratios between frequencies.
#
# For example:
#
# Octave → ratio 2:1
# Perfect fifth → ratio 3:2
# Perfect fourth → ratio 4:3
#
# These simple ratios form the mathematical foundation of musical harmony.
#
# The main objective of this project is to explore how mathematical relationships between frequencies explain musical harmony and how these relationships can be modeled and simulated using Python.
#
# Understanding these relationships is important not only for music theory but also for modern applications such as digital sound synthesis, music production, acoustic engineering, and audio signal processing.

# %%
3. Related Work

The relationship between mathematics and music has been studied for centuries. Early investigations began with the work of Pythagoras, who demonstrated that harmonious musical intervals correspond to simple ratios of string lengths and frequencies.

Later developments in music theory introduced the concept of musical tuning systems. One of the most widely used tuning systems today is the equal temperament system, which divides the octave into twelve equal steps.

Several modern researchers have explored the mathematical structure of music. Benson (2007) provides an extensive mathematical analysis of music theory, including harmonic series and tuning systems. Hall (2008) discusses the connections between mathematical patterns and musical structure.

Modern computational tools have also enabled new forms of research in music, including algorithmic composition, digital signal processing, and machine learning applications in music analysis.

This project builds upon these established mathematical concepts and demonstrates them using computational simulations and audio synthesis.

# %%
###3. Related work

# %%
###What other research has been done before me on this topic?

# %%
###4. Data

# %%
###What sources are there? What has been done before they came to me?

# %%
###5. Methods

# %% [markdown]
# ### What it will be used? How it will be applied? Restrictions? Assumptions?

# %%
### Visualization of Musical Frequencies

To better understand the mathematical structure of musical notes, we visualize how frequencies change across the chromatic scale.

Because each semitone increases frequency by a constant ratio (2^(1/12)), the resulting frequency distribution follows an exponential pattern.

# %%
import numpy as np
import matplotlib.pyplot as plt

A4 = 440
semitone_ratio = 2 ** (1/12)

notes = [
"C","C#","D","D#","E","F",
"F#","G","G#","A","A#","B"
]

frequencies = []

for i in range(-9,3):
    freq = A4 * (semitone_ratio ** i)
    frequencies.append(freq)

plt.figure(figsize=(10,5))

plt.plot(notes, frequencies, marker='o')

plt.title("Chromatic Scale Frequencies")
plt.xlabel("Musical Notes")
plt.ylabel("Frequency (Hz)")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Visualization of Musical Interval Ratios
#
# Musical harmony arises from simple ratios between frequencies. The following plot compares several important musical intervals.

# %%
intervals = {
"Octave":2/1,
"Perfect Fifth":3/2,
"Perfect Fourth":4/3,
"Major Third":5/4,
"Minor Third":6/5
}

names = list(intervals.keys())
values = list(intervals.values())

plt.figure(figsize=(8,5))

plt.bar(names, values)

plt.title("Frequency Ratios of Musical Intervals")
plt.ylabel("Frequency Ratio")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Visualization of the Harmonic Series
#
# Musical instruments naturally produce multiple frequencies called harmonics. These frequencies follow integer multiples of the fundamental frequency.

# %%
base_freq = 440

harmonics = [base_freq * n for n in range(1,10)]

plt.figure(figsize=(8,5))

plt.stem(range(1,10), harmonics)

plt.title("Harmonic Series")
plt.xlabel("Harmonic Number")
plt.ylabel("Frequency (Hz)")

plt.show()

# %%
## - Obtain all metadata?

# %%
## - Test out some plots?

# %%
## - Analyze and Validate assumptions

# %%
### 6. Results

# %%
### - present the results

# %%
### 7. Discussion

# %%
### - What could be improved in the model

# %%
### - additional ideas for further reseatch? why is it interesting and relevant?

# %%
### 8. References

# %%
### 9. Appendixes - additional figures, diagrams, etc.
